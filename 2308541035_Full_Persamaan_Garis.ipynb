# %%
#1. Garis melewati 2 titik
#2. Garis diketahui gradien dan titik yang dilewati
#3. Mengikuti persamaan garis ax+by=c dan dx+ey=f

# %%
import matplotlib.pyplot as plt
import numpy as np


print("Terdapat 3 kasus")
print("1. Garis melewati 2 titik")
print("2. Garis diketahui gradien dan titik yang dilewati")
print("3. Mengikuti persamaan garis ax+by=c dan dx+ey=f")
kasus_35 = float(input("Kasus berapa yang ingin dikerjakan?"))

if kasus_35 == 1:
    print("Garis akan melewati 2 titik yang sudah diinput")
    print("Masukkan nilai x dan y untuk garis pertama")
    x1_35 = float(input("Masukkan nilai x1:"))
    y1_35 = float(input("Masukkan nilai y1:"))
    x2_35 = float(input("Masukkan nilai x2:"))
    y2_35 = float(input("Masukkan nilai y2:"))
    
    print("Masukkan nilai x dan y untuk garis kedua")
    x3_35 = float(input("Masukkan nilai x1:"))
    y3_35 = float(input("Masukkan nilai y1:"))
    x4_35 = float(input("Masukkan nilai x2:"))
    y4_35 = float(input("Masukkan nilai y2:"))
    
    m1_35 = (y2_35 - y1_35)/(x2_35 - x1_35)
    print("Gradien dari garis pertama adalah " + str(m1_35))
    #pgl1_35 = 
    m2_35 = (y4_35 - y3_35)/(x4_35 - x3_35)
    print("Gradien dari garis kedua adaalah " + str(m2_35))
    
    if m1_35 == m2_35:
        print("Dua garis sejajar karena gradiennya sama")
        print("Jadi garis dapat memiliki banyak solusi atau tidak memiliki solusi sama sekali")
    
    if m1_35*m2_35 == -1:
        print("Dua garis tegak lurus karena hasil kali kedua gradien adalah -1")
        print("Garis akan memiliki titik potong")
    
        tpx_35 = (m1_35*a_35-b_35-m2_35*e_35+f_35)/(m1_35-m2_35)
        tpy_35 = m2_35*(tpx_35-e_35)+f_35
        print("Kedua garis tersebut berpotongan di ({},{})".format(tpx_35,tpy_35))

        x_35=np.arange(-3,5,0.2)
        p1_35=plt.plot(x_35,m1_35*(x_35-x1_35)+y1_35)
        p2_35=plt.plot(x_35,m2_35*(x_35-x3_35)+y3_35)
        plt.plot(tpx_35,tpy_35,marker='o',markersize=6)
        plt.show()
    else:
        
        tpx_35 = (m1_35*x1_35-y1_35-m2_35*x3_35+y3_35)/(m1_35-m2_35)
        tpy_35 = m2_35*(tpx_35-x3_35)+y3_35
        print("Kedua garis tersebut berpotongan di ({},{})".format(tpx_35,tpy_35))
        
        x_35=np.arange(-3,5,0.2)
        p1_35=plt.plot(x_35,m1_35*(x_35-x1_35)+y1_35)
        p2_35=plt.plot(x_35,m2_35*(x_35-x3_35)+y3_35)
        plt.plot(tpx_35,tpy_35,marker='o',markersize=6)
        plt.show()


elif kasus_35 == 2:
    print("Garis diketahui gradien dan titik yang dilewati")
    
    m1_35 = float(input("Gradien dari garis pertama adalah "))
    x1_35 = float(input("Masukkan nilai x yang dilewati garis pertama:"))
    y1_35 = float(input("Masukkan nilai y yang dilewati garis pertama:"))
    print("Jadi persamaan garis pertama adalah y={}(x-{})+{}". format(m1_35,x1_35,y1_35))
    
    m2_35 = float(input("Gradien dari garis kedua adalah "))
    x2_35 = float(input("Masukkan nilai x yang dilewati garis kedua:"))
    y2_35 = float(input("Masukkan nilai y yang dilewati garis kedua:"))
    print("Jadi persamaan garis kedua adalah y={}(x-{})+{}". format(m2_35,x2_35,y2_35))
    
    c1_35 = -m1_35 * x1_35 + y1_35
    c2_35 = -m2_35 * x2_35 + y2_35
    
    if m1_35 == m2_35:
        print("Garis sejajar atau berhimpit sehingga tidak berpotongan")
        
        if c1_35 == c2_35:
            print("Kedua garis berhimpit sehingga garis memiliki banyak solusi")
            
            x_35=np.arange(-3,5,0.2)
            p1_35=plt.plot(x_35,m1_35*(x_35-x1_35)+y1_35)
            p2_35=plt.plot(x_35,m2_35*(x_35-x2_35)+y2_35)
            plt.plot(tpx_35,tpy_35,marker='o',markersize=6)
            plt.show()
        
        else:
            print("Kedua garis sejajar sehingga garis memiliki banyak solusi")
            
            x_35=np.arange(-3,5,0.2)
            p1_35=plt.plot(x_35,m1_35*(x_35-x1_35)+y1_35)
            p2_35=plt.plot(x_35,m2_35*(x_35-x2_35)+y2_35)
            plt.plot(tpx_35,tpy_35,marker='o',markersize=6)
            plt.show()
    else:
        print("Garis akan memiliki titik potong")
        tpx_35 = (m1_35*x1_35-y1_35-m2_35*x2_35+y2_35)/(m1_35-m2_35)
        tpy_35 = m2_35*(tpx_35-x2_35)+y2_35
        print("Kedua garis tersebut berpotongan di ({},{})".format(tpx_35,tpy_35))
        
        x_35=np.arange(-3,5,0.2)
        p1_35=plt.plot(x_35,m1_35*(x_35-x1_35)+y1_35)
        p2_35=plt.plot(x_35,m2_35*(x_35-x2_35)+y2_35)
        plt.plot(tpx_35,tpy_35,marker='o',markersize=6)
        plt.show()


elif kasus_35 == 3:
    print("Garis memenuhi bentuk persamaan garis ax+by=c")
    print("Masukkan persamaan garis pertama yang memenuhi ax+by=c")
    a1_35 = float(input("Masukkan nilai a:"))
    b1_35 = float(input("Masukkan nilai b:"))
    c1_35 = float(input("Masukkan nilai c:"))
    
    print("Garis memenuhi bentuk persamaan garis ax+by=c")
    print("Masukkan persamaan garis kedua yang memenuhi ax+by=c")
    a2_35 = float(input("Masukkan nilai a:"))
    b2_35 = float(input("Masukkan nilai b:"))
    c2_35 = float(input("Masukkan nilai c:"))
    
    m1_35 = a1_35
    m2_35 = a2_35
    
    if m1_35 == m2_35:
        print("Garis sejajar atau berhimpit sehingga tidak berpotongan")
        print("Garis dapat memiliki banyak solusi atau tidak memiliki solusi")
        
        c1_35 = -m1_35 * x1_35 + y1_35
        c2_35 = -m2_35 * x2_35 + y2_35
    
        if c1_35 == c2_35:
            print("Kedua garis berhimpit sehingga garis memiliki banyak solusi")
        else:
            print("Kedua garis sejajar sehingga garis memiliki banyak solusi")
    else:
        tpx_35 = (m1_35*x1_35-y1_35-m2_35*x2_35+y2_35)/(m1_35-m2_35)
        tpy_35 = m2_35*(tpx_35-x2_35)+y2_35
        print("Kedua garis tersebut berpotongan di ({},{})".format(tpx_35,tpy_35))
        
        x_35=np.arange(-3,5,0.2)
        p1_35=plt.plot(x_35,m1_35*(x_35-x1_35)+y1_35)
        p2_35=plt.plot(x_35,m2_35*(x_35-x2_35)+y2_35)
        plt.plot(tpx_35,tpy_35,marker='o',markersize=6)
        plt.show()
    
    
    
    
else:
    print("Maaf kasus tidak dapat diselesaikan")
# Out:
# Terdapat 3 kasus
# 1. Garis melewati 2 titik
# 2. Garis diketahui gradien dan titik yang dilewati
# 3. Mengikuti persamaan garis ax+by=c dan dx+ey=f
# Kasus berapa yang ingin dikerjakan? 3
# Garis memenuhi bentuk persamaan garis ax+by=c
# Masukkan persamaan garis pertama yang memenuhi ax+by=c
# Masukkan nilai a: 2
# Masukkan nilai b: 3
# Masukkan nilai c: 4
# Garis memenuhi bentuk persamaan garis ax+by=c
# Masukkan persamaan garis kedua yang memenuhi ax+by=c
# Masukkan nilai a: 4
# Masukkan nilai b: 3
# Masukkan nilai c: 4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 138
#     136         print("Kedua garis sejajar sehingga garis memiliki banyak solusi")
#     137 else:
# --> 138     tpx_35 = (m1_35*x1_35-y1_35-m2_35*x2_35+y2_35)/(m1_35-m2_35)
#     139     tpy_35 = m2_35*(tpx_35-x2_35)+y2_35
# ...
