# %%
print('Selamat datang di kuis dadakan tidak berhadiah')
print("Oh iya, sebelum itu nama kamu siapa?")
nama_35 = input("Masukkan nama:")
print("Salam Kenal,",nama_35)
print ("")
      
print("Sebelum mulai kuis, kita pemanasan dulu yuk!")
print ("")
      
print("Apa kamu sudah makan?")
makan_35 = input("Sudah atau belum? :")
if makan_35 =="Sudah": print("MANTAP!!!!")
elif makan_35 == "sudah" : print("MANTAP!!!!")
else: print("Yahhh, makan ya nanti><")
print("")

siap_35 = input("Siap atau tidak jawab kuis: ")
if siap_35 == "Siap" :
    print ("Yuk mulai!")
    print ("Yuk mulai!")
    print("")
    print("")
        
    penjumlahan_35=5
    while penjumlahan_35:
        penjumlahan_35 = input("3+2=")
        if penjumlahan_35 == "5" : 
            print("Yeayy betul!")
            break
        else : 
            print("Yakin?") 
            
            penjumlahan_35 = input("3+2=")
            if penjumlahan_35 == "5" : print("Yeayy akhirnya betul!")
            else : print("Belajar dulu deh, baru jawab kuis ini")   
            break
elif siap_35 == "siap" :
    print ("Yuk mulai!")
    print("")
    print("")
        
    penjumlahan_35=5
    while penjumlahan_35:
        penjumlahan_35 = input("3+2=")
        if penjumlahan_35 == "5" : 
            print("Yeayy betul!")
            break
        else : 
            print("Yakin?") 
            
            penjumlahan_35 = input("3+2=")
            if penjumlahan_35 == "5" : print("Yeayy akhirnya betul!")
            else : print("Belajar dulu deh, baru jawab kuis ini")   
            break
# Out:
# Selamat datang di kuis dadakan tidak berhadiah
# Oh iya, sebelum itu nama kamu siapa?
# Masukkan nama: p
# Salam Kenal, p
#
# Sebelum mulai kuis, kita pemanasan dulu yuk!
#
# Apa kamu sudah makan?
# Sudah atau belum? : p
# Yahhh, makan ya nanti><
# Siap atau tidak jawab kuis:  Siap
# Yuk mulai!
# Yuk mulai!
# 3+2= 4
# Yakin?
# 3+2= 3
# Belajar dulu deh, baru jawab kuis ini
