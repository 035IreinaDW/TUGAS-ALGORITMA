# %%
import numpy as np

a_35 = np.array([1,2,3])
print(a_35)
b=a_35.dtype
print(b)

# %%
import numpy as np

b_35 = np.array([[[5,7,8,9], [1,2,3,4]],
               [[7,6,8,1], [9,2,5,0]]])
print(b_35)
print(b_35.ndim)
print(b_35.shape)
print(b_35[:,1])

# %%
import numpy as np

a_35 = np.array([])
baris_35 = int(input("Size yang diinginkan:"))
matriks = []
for i in range(baris_35):
    c_35 = int(input("Entry:"))
    a_35 = np.append(a_35, c_35)
print(a_35)

# %%
import numpy as np
matriks = []
for i in range(3):
    user_input = input(f'enter the value {[i]}:').split()
    matriks.append(user_input)
    arr = np.array(matriks, dtype=int)
print(arr)

# %%
import numpy as np

zero_35 = np.zeros((6,6))
matriks_35 = np.eye(6)
eye_35 = 3*matriks_35
print(eye_35)

satu_35 = np.ones((3,3))
identitas_35 = np.identity(3)*3
akhir_35 = satu_35 + identitas_35
print(akhir_35)

eye_35[1:4, 1:4] = akhir_35
print(eye_35)

# %%
import numpy as np

m_35 = np.array([[2,7,2,0], [3,1,5,9]])
print(m_35)

print()
copy_35 = m_35
print(copy_35)

print()
print(m_35.copy())

# %%
import numpy as np

data1_35 = np.array([9,8,7,6])
data2_35 = np.array([2,5,3,1])

print(data1_35+5)
print(data2_35+11)
print(data1_35+data2_35)
print(data1_35-data2_35)
print(data2_35/data1_35)
print(data1_35*data2_35)
print(data1_35**3)

# %%
import numpy as np
data3_35 = np.array([6,4,8,2])

print(np.cos(data3_35))
print(np.sin(data3_35))
print(np.tan(data3_35))
print(1/np.cos(data3_35))

# %%
import numpy as np

perkalian1_35 = np.array([[9,8,7,6],[5,2,4,3]])
perkalian2_35 = np.array([[2,5,], [3,1], [0,3], [2,1]])
hasil_35 = np.matmul(perkalian1_35, perkalian2_35)
print(hasil_35)


hasil2_35 = np.dot(hasil_35, perkalian1_35)
print(hasil2_35)

# %%
import numpy as np

matriks_35 =np.random.rand(2,4)
print(matriks_35)
print()
print(np.sort(matriks_35))
print()
min_35 = np.min(matriks_35)
print(min_35)
max_35 = np.max(matriks_35)
print(max_35)
sum_35 = np.sum(matriks_35)
print(sum_35)
