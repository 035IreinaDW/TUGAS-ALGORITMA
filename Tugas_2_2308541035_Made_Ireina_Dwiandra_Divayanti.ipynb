# %%
#2.4
nama_35 = input("Nama =")
gender_35 = input("Jenis kelamin =")
tempat_lahir_35 = input("Tempat lahir =")
tanggal_lahir_35 = input("Tanggal lahir =")
pekerjaan_35 = input("Pekerjaan = ")
print(f'{nama_35} yang berjenis kelamin {gender_35} lahir di {tempat_lahir_35} pada tanggal {tanggal_lahir_35} adalah seorang {pekerjaan_35}')

# %%
#2.5

favorit_35 = "TXT adalah grup kpop favoritku"
print (favorit_35[5])
print (favorit_35[3:-1])
print (favorit_35[8:-5:10])
print (favorit_35[:-12])
print (favorit_35[:])

# %%
#2.6

favorit_35 = "TXT adalah grup kpop favoritku"
favorit_35.upper()
favorit_35.find("txt")
favorit_35.replace("TXT","Seventeen")
print("KPOP" in favorit_35)

# %%
#2.7

#Menghitung keliling persegi panjang

P_35 = float(input("Panjang ="))
l_35 = float(input ("Lebar =" ))
keliling_persegi_panjang_35 = 2*(P_35 + l_35)
print("Keliling persegi panjang =" + str(keliling_persegi_panjang_35))

# %%
#2.8

a_35 = int(input("Masukkan nilai a ="))
b_35 = int(input("Masukkan nilai b ="))
print (a_35>b_35)
print (a_35<b_35)
print (a_35>=b_35)
print (a_35<=b_35)
print (a_35==b_35)
print (a_35!=b_35)

# %%
#2.9

mtk_35 = 38
seventeen_35 = 13

print(mtk_35 > 10 and seventeen_35 < 17)
print(mtk_35 > 10 or seventeen_35 < 17)
print(not(mtk_35 > 10 and seventeen_35 < 17))
print(mtk_35 == 70 or seventeen_35 == 17)
print(not(mtk_35 == 70 or seventeen_35 == 17))
# Out:
# True
# True
# False
# False
# True
