# %%
#2.12

angka_35 = [1,2,3,4,5]
warna_35 = ["Merah", "Kuning", "Hijau", "Biru", "Hitam"]
kelas_35 = ["MIPA", 1, 2, 3, "IPS", 1, 2]

print(angka_35)
print(warna_35)
print(kelas_35)
print(kelas_35[-2])
warna_35[3] = "Silver"
print(warna_35[3:6])
kelas_35[3] = "Bahasa"
print(kelas_35)

# %%
#2.13

barang_35 = ["Dompet", "Earphone", "Masker", "Powerbank", "Handphone"]
barang_35.append("Charger")
print(barang_35)
barang_35.remove("Earphone")
print(barang_35)
barang_35.insert(5,"Tisu")
print(barang_35)
print(len(barang_35))
print('Tisu' in barang_35)
print('handphone' in barang_35)

# %%
#2.14

baju_35 = ["Kaos", "Kemeja", "Polo", "Blouse"]
for jenis in baju_35:
        print(f"Saya punya satu " + jenis)
# Out:
# Saya punya satu Kaos
# Saya punya satu Kemeja
# Saya punya satu Polo
# Saya punya satu Blouse
